# %% [markdown]
# <a href="https://colab.research.google.com/github/ivansaldivar/varios/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Math

display(Math(r'$\sqrt{3x-1}+(1+x)^2$'))
# Out:
# $\displaystyle \sqrt{3x-1}+(1+x)^2$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from IPython.display import display, Math

def equation(x):
  return ((1+x)**2)

x = np.linspace(-100, 100,  100)
y = equation(x)

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")

plt.show()
